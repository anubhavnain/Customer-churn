# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
df=pd.read_excel("clean1.xlsx")

# %%
df.head()
# Out:
#    Customer ID  Order ID Gender                State PaymentStatus  \
# 0          493   2095543    NaN  Mumbai(Maharashtra)          Paid
# 1         2157   1918551    NaN           Tamil Nadu      Refunded
# 2         2300   1809194      M          Maharashtra          Paid
# 3         2397   1939063    NaN          Maharashtra          Paid
# 4         2397   1939063    NaN          Maharashtra          Paid
#
#       Order Status Payment Method  FinalAmt  OrderDate   Courier name  \
# 0        Delivered            dcc    1701.0 2019-09-20      Delhivery
# 1  Return Received         Wallet     837.0 2019-07-18      Delhivery
# 2        Delivered         Wallet     994.0 2019-06-02  Fedex Economy
# 3        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
# 4        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
#
#             Timestamp   Mode        Issue Category         Issue Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8327 entries, 0 to 8326
# Data columns (total 16 columns):
# Customer ID        8327 non-null int64
# Order ID           8327 non-null int64
# Gender             3057 non-null object
# State              8327 non-null object
# PaymentStatus      8325 non-null object
# Order Status       8327 non-null object
# Payment Method     8327 non-null object
# FinalAmt           8327 non-null float64
# OrderDate          8327 non-null datetime64[ns]
# Courier name       8327 non-null object
# Timestamp          8327 non-null datetime64[ns]
# Mode               8327 non-null object
# Issue Category     8327 non-null object
# Issue Type         8327 non-null object
# Priority           8327 non-null object
# Resolution Date    7873 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
df.drop('Issue Type',axis=1)
# Out:
#       Customer ID  Order ID Gender                State PaymentStatus  \
# 0             493   2095543    NaN  Mumbai(Maharashtra)          Paid
# 1            2157   1918551    NaN           Tamil Nadu      Refunded
# 2            2300   1809194      M          Maharashtra          Paid
# 3            2397   1939063    NaN          Maharashtra          Paid
# 4            2397   1939063    NaN          Maharashtra          Paid
# ...           ...       ...    ...                  ...           ...
# 8322      1521588   2109577    NaN        Uttar Pradesh          Paid
# 8323      1522179   2110700    NaN                Delhi       Pending
# 8324      1522717   2111783    NaN          Maharashtra          Paid
# 8325      1523054   2112421    NaN            Karnataka          Paid
# 8326      1526832   2122107    NaN           Tamil Nadu          Paid
#
#          Order Status Payment Method  FinalAmt  OrderDate    Courier name  \
# ...

# %%
df.head()
# Out:
#    Customer ID  Order ID Gender                State PaymentStatus  \
# 0          493   2095543    NaN  Mumbai(Maharashtra)          Paid
# 1         2157   1918551    NaN           Tamil Nadu      Refunded
# 2         2300   1809194      M          Maharashtra          Paid
# 3         2397   1939063    NaN          Maharashtra          Paid
# 4         2397   1939063    NaN          Maharashtra          Paid
#
#       Order Status Payment Method  FinalAmt  OrderDate   Courier name  \
# 0        Delivered            dcc    1701.0 2019-09-20      Delhivery
# 1  Return Received         Wallet     837.0 2019-07-18      Delhivery
# 2        Delivered         Wallet     994.0 2019-06-02  Fedex Economy
# 3        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
# 4        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
#
#             Timestamp   Mode        Issue Category         Issue Type  \
# ...

# %%
df.duplicated().sum()
# Out:
# 530

# %%
df[df.duplicated()]
# Out:
#       Customer ID  Order ID Gender        State PaymentStatus  \
# 84          24606   1873458    NaN  Maharashtra      Refunded
# 85          24606   1873458    NaN  Maharashtra      Refunded
# 86          24606   1873458    NaN  Maharashtra      Refunded
# 199         78398   1817920      M    Karnataka      Refunded
# 200         78398   1817920      M    Karnataka      Refunded
# ...           ...       ...    ...          ...           ...
# 7693      1453098   1962032    NaN  Maharashtra          Paid
# 7701      1453381   1962542    NaN  Maharashtra      Refunded
# 7702      1453381   1962542    NaN  Maharashtra      Refunded
# 7703      1453381   1962542    NaN  Maharashtra      Refunded
# 7752      1457642   1968963    NaN        Assam          Paid
#
#          Order Status Payment Method  FinalAmt  OrderDate   Courier name  \
# 84    Return Received            dcc    1349.0 2019-06-29      Delhivery
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#       Customer ID  Order ID Gender                State PaymentStatus  \
# 3564      1142325   2038090    NaN          Uttarakhand          Paid
# 5958      1405566   1878869      M            Karnataka       Pending
# 3529      1133367   1893013    NaN              Gujarat          Paid
# 2716       916434   1957157    NaN  Mumbai(Maharashtra)          Paid
# 5724      1402976   1872588    NaN        Uttar Pradesh       Pending
#
#          Order Status Payment Method  FinalAmt  OrderDate Courier name  \
# 3564        Delivered            COD      51.0 2019-08-28    Delhivery
# 5958        Delivered            dcc    1342.0 2019-06-30    Delhivery
# 3529        Delivered            COD    3959.0 2019-07-05    Delhivery
# 2716  Return Received            COD     210.0 2019-08-04    Delhivery
# 5724        Delivered         Wallet     785.0 2019-06-28    Delhivery
#
#                Timestamp   Mode        Issue Category       Issue Type  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID           0
# Order ID              0
# Gender             4923
# State                 0
# PaymentStatus         2
# Order Status          0
# Payment Method        0
# FinalAmt              0
# OrderDate             0
# Courier name          0
# Timestamp             0
# Mode                  0
# Issue Category        0
# Issue Type            0
# Priority              0
# Resolution Date     423
# dtype: int64

# %%
df.Gender.value_counts()
# Out:
# M         2074
# F          799
# Others       1
# Name: Gender, dtype: int64

# %%
df['Sex']=df.Gender.map({'M':1, 'F':0})

# %%
df.head()
# Out:
#    Customer ID  Order ID Gender                State PaymentStatus  \
# 0          493   2095543    NaN  Mumbai(Maharashtra)          Paid
# 1         2157   1918551    NaN           Tamil Nadu      Refunded
# 2         2300   1809194      M          Maharashtra          Paid
# 3         2397   1939063    NaN          Maharashtra          Paid
# 4         2397   1939063    NaN          Maharashtra          Paid
#
#       Order Status Payment Method  FinalAmt  OrderDate   Courier name  \
# 0        Delivered            dcc    1701.0 2019-09-20      Delhivery
# 1  Return Received         Wallet     837.0 2019-07-18      Delhivery
# 2        Delivered         Wallet     994.0 2019-06-02  Fedex Economy
# 3        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
# 4        Delivered            dcc    1860.0 2019-07-28  Fedex Economy
#
#             Timestamp   Mode        Issue Category         Issue Type  \
# ...

# %%
data=df.drop('Gender',axis=1)

# %%
data['FinalAmt'].fillna(data['FinalAmt'].median(),inplace=True)

# %%
data.head(15)
# Out:
#     Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0           493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1          2157   1918551           Tamil Nadu      Refunded  Return Received
# 2          2300   1809194          Maharashtra          Paid        Delivered
# 3          2397   1939063          Maharashtra          Paid        Delivered
# 4          2397   1939063          Maharashtra          Paid        Delivered
# 5          2397   1939063          Maharashtra          Paid        Delivered
# 6          2482   1867884          Maharashtra          Paid        Delivered
# 7          2781   2069716          Maharashtra          Paid        Delivered
# 8          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 9          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 10         3288   1931921              Gujarat       Pending        Delivered
# ...

# %%
data['Sex'].fillna(data['Sex'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Customer ID          0
# Order ID             0
# State                0
# PaymentStatus        2
# Order Status         0
# Payment Method       0
# FinalAmt             0
# OrderDate            0
# Courier name         0
# Timestamp            0
# Mode                 0
# Issue Category       0
# Issue Type           0
# Priority             0
# Resolution Date    423
# Sex                  0
# dtype: int64

# %%
a=pd.isnull(data["Resolution Date"]) 
data[a]
# Out:
#       Customer ID  Order ID          State PaymentStatus     Order Status  \
# 1079       409023   2061238      Karnataka      Refunded  Return Received
# 1096       412857   1828119    Maharashtra       Pending        Delivered
# 1104       415601   2048196    Maharashtra          Paid        Delivered
# 1107       416735   2050166    Maharashtra          Paid  Return Received
# 1130       427344   1748159         Odisha      Refunded  Return Received
# ...           ...       ...            ...           ...              ...
# 8221      1506622   2077488      Karnataka      Refunded  Return Received
# 8239      1507952   2080500          Delhi       Pending        Cancelled
# 8285      1513324   2091813  Uttar Pradesh      Refunded  Return Received
# 8293      1514160   2093510        Gujarat      Refunded  Return Received
# 8295      1514708   2095306          Delhi          Paid  Return Received
#
#      Payment Method  FinalAmt  OrderDate Courier name  Timestamp  \
# ...

# %%
data['Resolution Date'].fillna(data['Timestamp'],inplace=True)

# %%
data['Resolution Date']
# Out:
# 0      2019-09-21
# 1      2019-08-01
# 2      2019-06-27
# 3      2019-07-31
# 4      2019-07-31
#           ...
# 8322   2019-09-25
# 8323   2019-09-26
# 8324   2019-09-27
# 8325   2019-09-27
# 8326   2019-09-30
# Name: Resolution Date, Length: 7797, dtype: datetime64[ns]

# %%
data.shape
# Out:
# (7797, 16)

# %%
data.dropna(how = 'any').shape
# Out:
# (7795, 16)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Customer ID        0
# Order ID           0
# State              0
# PaymentStatus      0
# Order Status       0
# Payment Method     0
# FinalAmt           0
# OrderDate          0
# Courier name       0
# Timestamp          0
# Mode               0
# Issue Category     0
# Issue Type         0
# Priority           0
# Resolution Date    0
# Sex                0
# dtype: int64

# %%
data.head()
# Out:
#    Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0          493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1         2157   1918551           Tamil Nadu      Refunded  Return Received
# 2         2300   1809194          Maharashtra          Paid        Delivered
# 3         2397   1939063          Maharashtra          Paid        Delivered
# 4         2397   1939063          Maharashtra          Paid        Delivered
#
#   Payment Method  FinalAmt  OrderDate   Courier name           Timestamp  \
# 0            dcc    1701.0 2019-09-20      Delhivery 2019-09-21 00:00:00
# 1         Wallet     837.0 2019-07-18      Delhivery 2019-07-30 00:00:00
# 2         Wallet     994.0 2019-06-02  Fedex Economy 2019-06-26 00:00:00
# 3            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 00:00:00
# 4            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 11:23:13
#
# ...

# %%
data['Days_taken']=data['Resolution Date']- data['Timestamp']
data['Days_taken']=data['Days_taken']/np.timedelta64(1,'D')

# %%
data.tail()
# Out:
#       Customer ID  Order ID          State PaymentStatus Order Status  \
# 8322      1521588   2109577  Uttar Pradesh          Paid    Delivered
# 8323      1522179   2110700          Delhi       Pending    Cancelled
# 8324      1522717   2111783    Maharashtra          Paid    Delivered
# 8325      1523054   2112421      Karnataka          Paid    Delivered
# 8326      1526832   2122107     Tamil Nadu          Paid    Delivered
#
#      Payment Method  FinalAmt  OrderDate    Courier name  Timestamp  \
# 8322            COD    648.15 2019-09-25       Delhivery 2019-09-25
# 8323            COD    751.00 2019-09-25       Delhivery 2019-09-26
# 8324         Wallet   1152.00 2019-09-26  Rapid Delivery 2019-09-27
# 8325         Wallet   1677.00 2019-09-26       Delhivery 2019-09-27
# 8326         Wallet    942.00 2019-09-29       Delhivery 2019-09-30
#
#               Mode        Issue Category               Issue Type Priority  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7795 entries, 0 to 8326
# Data columns (total 17 columns):
# Customer ID        7795 non-null int64
# Order ID           7795 non-null int64
# State              7795 non-null object
# PaymentStatus      7795 non-null object
# Order Status       7795 non-null object
# Payment Method     7795 non-null object
# FinalAmt           7795 non-null float64
# OrderDate          7795 non-null datetime64[ns]
# Courier name       7795 non-null object
# Timestamp          7795 non-null datetime64[ns]
# Mode               7795 non-null object
# Issue Category     7795 non-null object
# Issue Type         7795 non-null object
# Priority           7795 non-null object
# Resolution Date    7795 non-null datetime64[ns]
# Sex                7795 non-null float64
# Days_taken         7795 non-null float64
# dtypes: datetime64[ns](3), float64(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#         Customer ID      Order ID      FinalAmt          Sex   Days_taken
# count  7.795000e+03  7.795000e+03   7795.000000  7795.000000  7795.000000
# mean   1.053447e+06  1.917684e+06   1128.549618     0.897498     7.057627
# std    4.461159e+05  8.066575e+04    881.091515     0.303326    32.549861
# min    4.930000e+02  3.617850e+05      0.000000     0.000000  -204.000000
# 25%    7.277180e+05  1.873529e+06    523.000000     1.000000    -0.486806
# 50%    1.287111e+06  1.901440e+06    981.000000     1.000000     0.000000
# 75%    1.410910e+06  1.947554e+06   1348.500000     1.000000     0.000000
# max    1.526832e+06  2.122107e+06  11389.000000     1.000000   223.536111

# %%
data=data.replace([-119,-117,-109,-61,-59,-58,-56,-37,-30,-28,-20,-18,-16,-13,-10,-9,-8,-7,-5,-4,-3,-2,-1],np.NaN)

# %%
data.describe()
# Out:
#         Customer ID      Order ID      FinalAmt          Sex   Days_taken
# count  7.795000e+03  7.795000e+03   7795.000000  7795.000000  7654.000000
# mean   1.053447e+06  1.917684e+06   1128.549618     0.897498     7.507212
# std    4.461159e+05  8.066575e+04    881.091515     0.303326    32.485158
# min    4.930000e+02  3.617850e+05      0.000000     0.000000  -204.000000
# 25%    7.277180e+05  1.873529e+06    523.000000     1.000000    -0.476884
# 50%    1.287111e+06  1.901440e+06    981.000000     1.000000     0.000000
# 75%    1.410910e+06  1.947554e+06   1348.500000     1.000000     0.000000
# max    1.526832e+06  2.122107e+06  11389.000000     1.000000   223.536111

# %%
data.isnull().sum()
# Out:
# Customer ID          0
# Order ID             0
# State                0
# PaymentStatus        0
# Order Status         0
# Payment Method       0
# FinalAmt             0
# OrderDate            0
# Courier name         0
# Timestamp            0
# Mode                 0
# Issue Category       0
# Issue Type           0
# Priority             0
# Resolution Date      0
# Sex                  0
# Days_taken         141
# dtype: int64

# %%
data.fillna({'Days_taken' : 0},inplace=True)

# %%
data.isnull().sum()
# Out:
# Customer ID        0
# Order ID           0
# State              0
# PaymentStatus      0
# Order Status       0
# Payment Method     0
# FinalAmt           0
# OrderDate          0
# Courier name       0
# Timestamp          0
# Mode               0
# Issue Category     0
# Issue Type         0
# Priority           0
# Resolution Date    0
# Sex                0
# Days_taken         0
# dtype: int64

# %%
plt.hist(data['FinalAmt'].values)
plt.show()

# %%
print(data['Mode'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0              Email
# 1              Email
# 2              Email
# 3              Email
# 4               Call
#             ...
# 8322            Call
# 8323           Email
# 8324           Email
# 8325           Email
# 8326    Instagram Dm
# Name: Mode, Length: 7795, dtype: object>

# %%
mode_count=data['Mode'].value_counts()
sns.set(style="darkgrid")
sns.barplot(mode_count.index, mode_count.values, alpha=1)
plt.title('Frequency  of channel of resolution')
plt.ylabel('Number of Occurences', fontsize=12)
plt.xlabel('Mode', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %%
data.head()
# Out:
#    Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0          493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1         2157   1918551           Tamil Nadu      Refunded  Return Received
# 2         2300   1809194          Maharashtra          Paid        Delivered
# 3         2397   1939063          Maharashtra          Paid        Delivered
# 4         2397   1939063          Maharashtra          Paid        Delivered
#
#   Payment Method  FinalAmt  OrderDate   Courier name           Timestamp  \
# 0            dcc    1701.0 2019-09-20      Delhivery 2019-09-21 00:00:00
# 1         Wallet     837.0 2019-07-18      Delhivery 2019-07-30 00:00:00
# 2         Wallet     994.0 2019-06-02  Fedex Economy 2019-06-26 00:00:00
# 3            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 00:00:00
# 4            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 11:23:13
#
# ...

# %%
corr=data.corr()

# %%
sns.heatmap(corr)

# %%
#No. of Compaints raised by a particuar medium
data.groupby('Mode')['Issue Category'].count().plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel("Mode of Complaint")
plt.ylabel("No. of Complaints")
plt.show()

# %%
data.head()
# Out:
#    Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0          493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1         2157   1918551           Tamil Nadu      Refunded  Return Received
# 2         2300   1809194          Maharashtra          Paid        Delivered
# 3         2397   1939063          Maharashtra          Paid        Delivered
# 4         2397   1939063          Maharashtra          Paid        Delivered
#
#   Payment Method  FinalAmt  OrderDate   Courier name           Timestamp  \
# 0            dcc    1701.0 2019-09-20      Delhivery 2019-09-21 00:00:00
# 1         Wallet     837.0 2019-07-18      Delhivery 2019-07-30 00:00:00
# 2         Wallet     994.0 2019-06-02  Fedex Economy 2019-06-26 00:00:00
# 3            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 00:00:00
# 4            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 11:23:13
#
# ...

# %%
num = data._get_numeric_data()
num[num < 0] = 0

# %%
NumberComplaints= data.groupby(by='Customer ID', as_index=False)['Issue Category'].count()
NumberComplaints.columns= ['Customer ID' ,'Issue Category']
NumberComplaints.describe()
# Out:
#         Customer ID  Issue Category
# count  5.161000e+03     5161.000000
# mean   1.049430e+06        1.510366
# std    4.524386e+05        1.104755
# min    4.930000e+02        1.000000
# 25%    7.068980e+05        1.000000
# 50%    1.287129e+06        1.000000
# 75%    1.412382e+06        2.000000
# max    1.526832e+06       16.000000

# %%
total_spend = data.groupby(by='Customer ID', as_index=False)['FinalAmt'].sum()
total_spend.columns = ['CustomerID', 'FinalAmt']
total_spend.describe()
# Out:
#          CustomerID      FinalAmt
# count  5.161000e+03   5161.000000
# mean   1.049430e+06   1704.523207
# std    4.524386e+05   2084.956991
# min    4.930000e+02      0.000000
# 25%    7.068980e+05    628.000000
# 50%    1.287129e+06   1136.000000
# 75%    1.412382e+06   1990.000000
# max    1.526832e+06  36918.000000

# %%
data.groupby(['State','Issue Category']).size().unstack().plot(kind='bar', stacked=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
#No. of complaints of a particular type and raised through different modes
sns.countplot(x='Issue Category', hue='Mode', data=data)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation='vertical')
plt.show()

# %%
latest_resolve = data.groupby(by='Customer ID', as_index=False)['Resolution Date'].max()
latest_resolve.columns = ['Customer ID', 'LatestComplaint']
latest_resolve
# Out:
#       Customer ID LatestComplaint
# 0             493      2019-09-21
# 1            2157      2019-08-01
# 2            2300      2019-06-27
# 3            2397      2019-07-31
# 4            2482      2019-06-26
# ...           ...             ...
# 5156      1521588      2019-09-25
# 5157      1522179      2019-09-26
# 5158      1522717      2019-09-27
# 5159      1523054      2019-09-27
# 5160      1526832      2019-09-30
#
# [5161 rows x 2 columns]

# %%
latest_complaint = data.groupby(by='Customer ID', as_index=False)['Timestamp'].max()
latest_complaint.columns = ['Customer ID', 'LatestComplaint']
latest_complaint
# Out:
#       Customer ID     LatestComplaint
# 0             493 2019-09-21 00:00:00
# 1            2157 2019-07-30 00:00:00
# 2            2300 2019-06-26 00:00:00
# 3            2397 2019-07-31 11:36:03
# 4            2482 2019-06-26 00:00:00
# ...           ...                 ...
# 5156      1521588 2019-09-25 00:00:00
# 5157      1522179 2019-09-26 00:00:00
# 5158      1522717 2019-09-27 00:00:00
# 5159      1523054 2019-09-27 00:00:00
# 5160      1526832 2019-09-30 00:00:00
#
# [5161 rows x 2 columns]

# %%
data.head()
# Out:
#    Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0          493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1         2157   1918551           Tamil Nadu      Refunded  Return Received
# 2         2300   1809194          Maharashtra          Paid        Delivered
# 3         2397   1939063          Maharashtra          Paid        Delivered
# 4         2397   1939063          Maharashtra          Paid        Delivered
#
#   Payment Method  FinalAmt  OrderDate   Courier name           Timestamp  \
# 0            dcc    1701.0 2019-09-20      Delhivery 2019-09-21 00:00:00
# 1         Wallet     837.0 2019-07-18      Delhivery 2019-07-30 00:00:00
# 2         Wallet     994.0 2019-06-02  Fedex Economy 2019-06-26 00:00:00
# 3            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 00:00:00
# 4            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 11:23:13
#
# ...

# %%
print(data['Issue Category'].unique())
# Out:
# ['Shipping Delay/Issue' 'Ex/Return Request' 'Defective' 'Queries'
#  'Courier Delay' 'Refund Status' 'Tech Issues' 'Bad Quality'
#  'Refund Related' 'Suggestion' 'Wrong Product' 'Compliments' 'Flags']

# %%
#Average No. of days taken to solve a particular type of compaint
data.groupby('Issue Category')['Days_taken'].mean().plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel("Complaints")
plt.ylabel("Average No. of Days")
plt.show()

# %%
#No. of Complaints resolved in a particular month
data['Resolution Date'].map(lambda x: x.month).plot(kind='hist')
plt.show()

# %%
#No. of Customers to raise complaint of a particular type
data.groupby('Issue Category') ['Customer ID'].nunique().plot(kind='bar')
plt.xlabel("Complaints")
plt.ylabel("No. of Customers")
plt.show()

# %%
#Average No. of days taken to solve a Problem raised through a particular medium
data.groupby('Mode')['Days_taken'].mean().plot(kind='bar')
plt.xticks(rotation=90)
plt.xlabel("Mode of Complaints")
plt.ylabel("Average No. of Days")
plt.show()

# %%
a=data.groupby('Customer ID') ['Resolution Date'].nunique()

# %%
a
# Out:
# Customer ID
# 493        1
# 2157       1
# 2300       1
# 2397       1
# 2482       1
#           ..
# 1521588    1
# 1522179    1
# 1522717    1
# 1523054    1
# 1526832    1
# Name: Resolution Date, Length: 5161, dtype: int64

# %%
data=data.drop('Issue Type',axis=1)

# %%
data.rename(columns={'Issue Category':'Complaints_Type'},inplace=True)

# %%
data['Churn']=data.Complaints_Type.map({'Queries':1})

# %%
data.head()
# Out:
#    Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0          493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1         2157   1918551           Tamil Nadu      Refunded  Return Received
# 2         2300   1809194          Maharashtra          Paid        Delivered
# 3         2397   1939063          Maharashtra          Paid        Delivered
# 4         2397   1939063          Maharashtra          Paid        Delivered
#
#   Payment Method  FinalAmt  OrderDate   Courier name           Timestamp  \
# 0            dcc    1701.0 2019-09-20      Delhivery 2019-09-21 00:00:00
# 1         Wallet     837.0 2019-07-18      Delhivery 2019-07-30 00:00:00
# 2         Wallet     994.0 2019-06-02  Fedex Economy 2019-06-26 00:00:00
# 3            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 00:00:00
# 4            dcc    1860.0 2019-07-28  Fedex Economy 2019-07-31 11:23:13
#
# ...

# %%
data.isnull().sum()
# Out:
# Customer ID           0
# Order ID              0
# State                 0
# PaymentStatus         0
# Order Status          0
# Payment Method        0
# FinalAmt              0
# OrderDate             0
# Courier name          0
# Timestamp             0
# Mode                  0
# Complaints_Type       0
# Issue Type            0
# Priority              0
# Resolution Date       0
# Sex                   0
# Days_taken            0
# Churn              4522
# dtype: int64

# %%
data['Churn'].fillna(0,inplace=True)

# %%
data.head(15)
# Out:
#     Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0           493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1          2157   1918551           Tamil Nadu      Refunded  Return Received
# 2          2300   1809194          Maharashtra          Paid        Delivered
# 3          2397   1939063          Maharashtra          Paid        Delivered
# 4          2397   1939063          Maharashtra          Paid        Delivered
# 5          2397   1939063          Maharashtra          Paid        Delivered
# 6          2482   1867884          Maharashtra          Paid        Delivered
# 7          2781   2069716          Maharashtra          Paid        Delivered
# 8          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 9          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 10         3288   1931921              Gujarat       Pending        Delivered
# ...

# %%
data['Churn'].value_counts()
# Out:
# 0.0    4522
# 1.0    3273
# Name: Churn, dtype: int64

# %%
data['Days_taken']=data['Days_taken'].round()

# %%
data.head(15)
# Out:
#     Customer ID  Order ID                State PaymentStatus     Order Status  \
# 0           493   2095543  Mumbai(Maharashtra)          Paid        Delivered
# 1          2157   1918551           Tamil Nadu      Refunded  Return Received
# 2          2300   1809194          Maharashtra          Paid        Delivered
# 3          2397   1939063          Maharashtra          Paid        Delivered
# 4          2397   1939063          Maharashtra          Paid        Delivered
# 5          2397   1939063          Maharashtra          Paid        Delivered
# 6          2482   1867884          Maharashtra          Paid        Delivered
# 7          2781   2069716          Maharashtra          Paid        Delivered
# 8          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 9          3241   1886608  Mumbai(Maharashtra)          Paid      Undelivered
# 10         3288   1931921              Gujarat       Pending        Delivered
# ...

# %%
data.to_excel("Final_Target.xlsx")
